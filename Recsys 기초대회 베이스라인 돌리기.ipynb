# %%
# # 코드 다운로드
# !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000326/data/code.tar.gz

# # 데이터 다운로드
# !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000326/data/data.tar.gz

# # 압축 해제
# !tar -zxvf code.tar.gz
# !tar -zxvf data.tar.gz

# # 데이터 폴더 이동
# !mv data code

# %%
# requirement.txt 설치
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: pandas in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from -r requirement.txt (line 1)) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from -r requirement.txt (line 2)) (1.4.2)
# Requirement already satisfied: nltk in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from -r requirement.txt (line 3)) (3.8.1)
# Requirement already satisfied: transformers in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from -r requirement.txt (line 4)) (4.41.2)
# Requirement already satisfied: numpy>=1.23.2 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from pandas->-r requirement.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from pandas->-r requirement.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from pandas->-r requirement.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from pandas->-r requirement.txt (line 1)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from scikit-learn->-r requirement.txt (line 2)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from scikit-learn->-r requirement.txt (line 2)) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from scikit-learn->-r requirement.txt (line 2)) (2.2.0)
# Requirement already satisfied: click in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from nltk->-r requirement.txt (line 3)) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from nltk->-r requirement.txt (line 3)) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from nltk->-r requirement.txt (line 3)) (4.66.4)
# Requirement already satisfied: filelock in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (6.0.1)
# Requirement already satisfied: requests in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (2.32.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from transformers->-r requirement.txt (line 4)) (0.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers->-r requirement.txt (line 4)) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers->-r requirement.txt (line 4)) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirement.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from requests->transformers->-r requirement.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from requests->transformers->-r requirement.txt (line 4)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from requests->transformers->-r requirement.txt (line 4)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yoom618/anaconda3/lib/python3.11/site-packages (from requests->transformers->-r requirement.txt (line 4)) (2024.7.4)

# %%
# 설치 버전 확인 (pandas scikit-learn nltk transformers)
from importlib.metadata import version

for package in ['pandas', 'scikit-learn', 'nltk', 'transformers']:
    print(f'{package}: {version(package)}')
# Out:
# pandas: 2.2.2
# scikit-learn: 1.4.2
# nltk: 3.8.1
# transformers: 4.41.2

# %%
# 모델 학습 - FM
import time
start = time.time()

# !python main.py --model FM --device mps

print("time :", time.time() - start)
# Out:
# --------------- FM Load Data ---------------
# --------------- FM Train/Valid Split ---------------
# --------------- INIT FM ---------------
# --------------- FM TRAINING ---------------
#   0%|                                                    | 0/10 [00:00<?, ?it/s][Epoch 01/10]
# Train Loss: 4.196
# Valid Loss: 2.385 | MSE: 5.690 | MAE: 1.847
#  10%|████▍                                       | 1/10 [00:03<00:28,  3.18s/it][Epoch 02/10]
# Train Loss: 2.183
# Valid Loss: 2.246 | MSE: 5.047 | MAE: 1.722
#  20%|████████▊                                   | 2/10 [00:06<00:23,  2.97s/it][Epoch 03/10]
# Train Loss: 1.954
# Valid Loss: 2.216 | MSE: 4.915 | MAE: 1.691
#  30%|█████████████▏                              | 3/10 [00:08<00:20,  2.91s/it][Epoch 04/10]
# Train Loss: 1.811
# Valid Loss: 2.215 | MSE: 4.907 | MAE: 1.693
#  40%|█████████████████▌                          | 4/10 [00:11<00:17,  2.99s/it][Epoch 05/10]
# Train Loss: 1.705
# Valid Loss: 2.223 | MSE: 4.946 | MAE: 1.701
#  50%|██████████████████████                      | 5/10 [00:14<00:14,  2.96s/it][Epoch 06/10]
# Train Loss: 1.623
# Valid Loss: 2.239 | MSE: 5.018 | MAE: 1.723
#  60%|██████████████████████████▍                 | 6/10 [00:17<00:11,  2.99s/it][Epoch 07/10]
# Train Loss: 1.559
# Valid Loss: 2.255 | MSE: 5.087 | MAE: 1.728
#  70%|██████████████████████████████▊             | 7/10 [00:20<00:08,  3.00s/it][Epoch 08/10]
# Train Loss: 1.507
# Valid Loss: 2.273 | MSE: 5.169 | MAE: 1.744
#  80%|███████████████████████████████████▏        | 8/10 [00:23<00:05,  2.97s/it][Epoch 09/10]
# Train Loss: 1.464
# Valid Loss: 2.293 | MSE: 5.261 | MAE: 1.759
#  90%|███████████████████████████████████████▌    | 9/10 [00:27<00:03,  3.04s/it][Epoch 10/10]
# Train Loss: 1.430
# Valid Loss: 2.316 | MSE: 5.365 | MAE: 1.789
# 100%|███████████████████████████████████████████| 10/10 [00:30<00:00,  3.01s/it]
# --------------- FM PREDICT ---------------
# --------------- SAVE FM PREDICT ---------------
# time : 34.97864007949829

# %%
# 모델 학습 - FFM
import time
start = time.time()

# !python main.py --model FFM --device mps

print("time :", time.time() - start)
# Out:
# --------------- FFM Load Data ---------------
# --------------- FFM Train/Valid Split ---------------
# --------------- INIT FFM ---------------
# --------------- FFM TRAINING ---------------
#   0%|                                                    | 0/10 [00:00<?, ?it/s]^C
#   0%|                                                    | 0/10 [00:05<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/yoom618/Downloads/code_recsys/main.py", line 151, in <module>
#     main(args)
#   File "/Users/yoom618/Downloads/code_recsys/main.py", line 69, in main
#     model = train(args, model, data, logger, setting)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/Downloads/code_recsys/src/train/trainer.py", line 55, in train
#     y_hat = model(x)
#             ^^^^^^^^
#   File "/Users/yoom618/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/Downloads/code_recsys/src/models/FFM.py", line 70, in forward
#     y = self.linear(x).squeeze(1) + self.ffm(x)
#                                     ^^^^^^^^^^^
#   File "/Users/yoom618/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/Downloads/code_recsys/src/models/FFM.py", line 47, in forward
#     y.append(xv[f][:, g] * xv[g][:, f])
# KeyboardInterrupt
# time : 9.966091871261597

# %%
# 모델 학습 - WDN
import time
start = time.time()

# !python main.py --model WDN --device mps

print("time :", time.time() - start)
# Out:
# --------------- WDN Load Data ---------------
# --------------- WDN Train/Valid Split ---------------
# --------------- INIT WDN ---------------
# --------------- WDN TRAINING ---------------
#   0%|                                                    | 0/10 [00:00<?, ?it/s][Epoch 01/10]
# Train Loss: 5.101
# Valid Loss: 3.073 | MSE: 9.446 | MAE: 2.706
#  10%|████▍                                       | 1/10 [00:04<00:37,  4.13s/it][Epoch 02/10]
# Train Loss: 2.415
# Valid Loss: 2.384 | MSE: 5.683 | MAE: 1.926
#  20%|████████▊                                   | 2/10 [00:07<00:30,  3.77s/it][Epoch 03/10]
# Train Loss: 2.123
# Valid Loss: 2.354 | MSE: 5.544 | MAE: 1.868
#  30%|█████████████▏                              | 3/10 [00:11<00:25,  3.60s/it][Epoch 04/10]
# Train Loss: 1.921
# Valid Loss: 2.383 | MSE: 5.681 | MAE: 1.877
#  40%|█████████████████▌                          | 4/10 [00:14<00:20,  3.44s/it][Epoch 05/10]
# Train Loss: 1.770
# Valid Loss: 2.386 | MSE: 5.696 | MAE: 1.850
#  50%|██████████████████████                      | 5/10 [00:17<00:16,  3.35s/it][Epoch 06/10]
# Train Loss: 1.661
# Valid Loss: 2.378 | MSE: 5.659 | MAE: 1.843
#  60%|██████████████████████████▍                 | 6/10 [00:20<00:13,  3.33s/it][Epoch 07/10]
# Train Loss: 1.573
# Valid Loss: 2.426 | MSE: 5.888 | MAE: 1.874
#  70%|██████████████████████████████▊             | 7/10 [00:24<00:09,  3.33s/it][Epoch 08/10]
# Train Loss: 1.500
# Valid Loss: 2.431 | MSE: 5.912 | MAE: 1.877
#  80%|███████████████████████████████████▏        | 8/10 [00:27<00:06,  3.38s/it][Epoch 09/10]
# Train Loss: 1.448
# Valid Loss: 2.410 | MSE: 5.812 | MAE: 1.857
#  90%|███████████████████████████████████████▌    | 9/10 [00:30<00:03,  3.38s/it][Epoch 10/10]
# Train Loss: 1.402
# Valid Loss: 2.422 | MSE: 5.867 | MAE: 1.866
# 100%|███████████████████████████████████████████| 10/10 [00:34<00:00,  3.42s/it]
# --------------- WDN PREDICT ---------------
# --------------- SAVE WDN PREDICT ---------------
# time : 38.12054491043091

# %%
# 모델 학습
import time
start = time.time()

# !python main.py --model DCN --device mps

print("time :", time.time() - start)
# Out:
# --------------- DCN Load Data ---------------
# --------------- DCN Train/Valid Split ---------------
# --------------- INIT DCN ---------------
# --------------- DCN TRAINING ---------------
#   0%|                                                    | 0/10 [00:00<?, ?it/s][Epoch 01/10]
# Train Loss: 4.889
# Valid Loss: 9.350 | MSE: 87.422 | MAE: 8.900
#  10%|████▍                                       | 1/10 [00:03<00:35,  3.97s/it][Epoch 02/10]
# Train Loss: 2.429
# Valid Loss: 2.558 | MSE: 6.546 | MAE: 2.160
#  20%|████████▊                                   | 2/10 [00:07<00:29,  3.68s/it][Epoch 03/10]
# Train Loss: 2.175
# Valid Loss: 2.638 | MSE: 6.964 | MAE: 2.223
#  30%|█████████████▏                              | 3/10 [00:11<00:27,  3.90s/it][Epoch 04/10]
# Train Loss: 1.976
# Valid Loss: 2.377 | MSE: 5.651 | MAE: 1.899
#  40%|█████████████████▌                          | 4/10 [00:15<00:23,  3.84s/it][Epoch 05/10]
# Train Loss: 1.829
# Valid Loss: 2.939 | MSE: 8.641 | MAE: 2.505
#  50%|██████████████████████                      | 5/10 [00:18<00:18,  3.76s/it][Epoch 06/10]
# Train Loss: 1.726
# Valid Loss: 2.679 | MSE: 7.185 | MAE: 1.919
#  60%|██████████████████████████▍                 | 6/10 [00:22<00:14,  3.72s/it][Epoch 07/10]
# Train Loss: 1.650
# Valid Loss: 2.433 | MSE: 5.922 | MAE: 1.922
#  70%|██████████████████████████████▊             | 7/10 [00:26<00:10,  3.65s/it][Epoch 08/10]
# Train Loss: 1.590
# Valid Loss: 2.403 | MSE: 5.774 | MAE: 1.923
#  80%|███████████████████████████████████▏        | 8/10 [00:29<00:07,  3.58s/it][Epoch 09/10]
# Train Loss: 1.547
# Valid Loss: 2.372 | MSE: 5.629 | MAE: 1.859
#  90%|███████████████████████████████████████▌    | 9/10 [00:33<00:03,  3.66s/it][Epoch 10/10]
# Train Loss: 1.505
# Valid Loss: 2.909 | MSE: 8.466 | MAE: 2.447
# 100%|███████████████████████████████████████████| 10/10 [00:36<00:00,  3.69s/it]
# --------------- DCN PREDICT ---------------
# --------------- SAVE DCN PREDICT ---------------
# time : 40.75389814376831

# %%
# 모델 학습
import time
start = time.time()

# !python main.py --model NCF --device mps

print("time :", time.time() - start)
# Out:
# --------------- NCF Load Data ---------------
# --------------- NCF Train/Valid Split ---------------
# --------------- INIT NCF ---------------
# --------------- NCF TRAINING ---------------
#   0%|                                                    | 0/10 [00:00<?, ?it/s][Epoch 01/10]
# Train Loss: 5.421
# Valid Loss: 3.067 | MSE: 9.408 | MAE: 2.694
#  10%|████▍                                       | 1/10 [00:03<00:33,  3.76s/it][Epoch 02/10]
# Train Loss: 2.427
# Valid Loss: 2.309 | MSE: 5.333 | MAE: 1.866
#  20%|████████▊                                   | 2/10 [00:07<00:28,  3.50s/it][Epoch 03/10]
# Train Loss: 2.115
# Valid Loss: 2.362 | MSE: 5.580 | MAE: 1.895
#  30%|█████████████▏                              | 3/10 [00:10<00:23,  3.41s/it][Epoch 04/10]
# Train Loss: 1.905
# Valid Loss: 2.398 | MSE: 5.755 | MAE: 1.907
#  40%|█████████████████▌                          | 4/10 [00:13<00:20,  3.35s/it][Epoch 05/10]
# Train Loss: 1.751
# Valid Loss: 2.400 | MSE: 5.761 | MAE: 1.888
#  50%|██████████████████████                      | 5/10 [00:16<00:16,  3.33s/it][Epoch 06/10]
# Train Loss: 1.639
# Valid Loss: 2.413 | MSE: 5.823 | MAE: 1.884
#  60%|██████████████████████████▍                 | 6/10 [00:20<00:13,  3.39s/it][Epoch 07/10]
# Train Loss: 1.554
# Valid Loss: 2.423 | MSE: 5.871 | MAE: 1.889
#  70%|██████████████████████████████▊             | 7/10 [00:23<00:10,  3.41s/it][Epoch 08/10]
# Train Loss: 1.492
# Valid Loss: 2.419 | MSE: 5.852 | MAE: 1.882
#  80%|███████████████████████████████████▏        | 8/10 [00:27<00:06,  3.45s/it][Epoch 09/10]
# Train Loss: 1.443
# Valid Loss: 2.414 | MSE: 5.833 | MAE: 1.878
#  90%|███████████████████████████████████████▌    | 9/10 [00:30<00:03,  3.40s/it][Epoch 10/10]
# Train Loss: 1.400
# Valid Loss: 2.435 | MSE: 5.931 | MAE: 1.888
# 100%|███████████████████████████████████████████| 10/10 [00:34<00:00,  3.40s/it]
# --------------- NCF PREDICT ---------------
# --------------- SAVE NCF PREDICT ---------------
# time : 37.14994788169861

# %%
# 모델 학습
import time
start = time.time()

# !python main.py --model DeepCoNN --device mps --vector_create True

print("time :", time.time() - start)
# Out:
# --------------- DeepCoNN Load Data ---------------
# Create Item Summary Vector
#  46%|████████████████▍                   | 68491/149570 [46:24<58:46, 22.99it/s]

# %%
# 모델 학습 - CNN_FM
import time
start = time.time()

# !python main.py --model CNN_FM

print("time :", time.time() - start)
# Out:
# --------------- CNN_FM Load Data ---------------
# 100%|█████████████████████████████████| 149570/149570 [00:25<00:00, 5963.44it/s]
# --------------- CNN_FM Train/Valid Split ---------------
# --------------- INIT CNN_FM ---------------
# Traceback (most recent call last):
#   File "/Users/yoom618/Downloads/code_recsys/main.py", line 135, in <module>
#     main(args)
#   File "/Users/yoom618/Downloads/code_recsys/main.py", line 48, in main
#     model = models_load(args,data)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/Downloads/code_recsys/src/utils.py", line 48, in models_load
#     model = CNN_FM(args, data).to(args.device)
#             ^^^^^^^^^^^^^^^^^^
#   File "/Users/yoom618/Downloads/code_recsys/src/models/CNN_FM.py", line 16, in __init__
#     self.cnn = CNN_Base(
#                ^^^^^^^^^
# TypeError: CNN_Base.__init__() got an unexpected keyword argument 'input_dim'
# time : 28.68127989768982

# %%
# 앙상블 실행
# /submit/20240728_133605_NCF.csv 인 경우, `20240728_133605_NCF`만 작성해주면 됨

# !python ensemble.py --ensemble_files 20240728_133228_CNN_FM 20240728_133605_NCF
